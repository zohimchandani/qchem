# %%
import cudaq
from typing import List
import numpy as np 
from cudaq import spin
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import cupy as cp
from sklearn.metrics import roc_auc_score, roc_curve, auc

cudaq.set_target("nvidia")

df_input = cp.loadtxt("qc_pca_train_input_bace_12q2")
df_classes = cp.loadtxt("qc_pca_train_classes_bace_12q2") - 1
df_test_input = cp.loadtxt("qc_pca_test_input_bace_12q2")
df_test_classes = cp.loadtxt("qc_pca_test_classes_bace_12q2") - 1

m = df_classes.size  #Number of data samples 
num_classes = int(max(df_classes)) + 1 #Number of classes
num_qubits = df_input.shape[1]
ansatz_layers = 1
maxiter = 1
num_theta = num_qubits * ansatz_layers
# theta_values = np.zeros(num_theta)
theta_values = cp.array([2.262186420621457, 0.978574311506747])
data_values  = df_input
class_values = df_classes

def gen_default_prob_class(num_qubits, num_classes):
    prob_class = cp.zeros(2**num_qubits)
    for i in range(2**num_qubits):
        prob_class[i] = i % num_classes
    return prob_class

prob_class = gen_default_prob_class(num_qubits, num_classes)

def softmax(x):
    return cp.exp(x)/sum(cp.exp(x))

# %%
@cudaq.kernel
def kernel(data: cp.ndarray, theta: cp.ndarray):
    
    q = cudaq.qvector(num_qubits)
    
    #Data encoding
    for i in range(num_qubits):
        ry(data[i], q[num_qubits-i-1])
    for i in range(num_qubits - 1):
        x.ctrl(q[i + 1], q[i])

    #Parameterised ansatz
    for i in range(ansatz_layers):
        for j in range(num_qubits):
            ry(theta[i * num_qubits + j], q[num_qubits-j-1])
        for j in range(num_qubits - 1):
            x.ctrl(q[j + 1], q[j])

def cost_function(theta_values):
    cost = 0.0
    for i in range(m):
        c = 0.0
        sv = cp.array(cudaq.get_state(kernel, data_values[i], theta_values))
        prob = softmax(cp.real(cp.abs(sv) ** 2))
        for j in range(2**num_qubits):
            if prob_class[j] == class_values[i]:
                c += prob[j]
        cost += -cp.log(c)
    cost = cost / m
    return cost

def find_prob(data, theta, classes):
    p = cp.zeros(len(data))
    for i in range(len(data)):
        c = 0.0
        sv = cp.array(cudaq.get_state(kernel, data[i], theta))
        prob = cp.real(cp.abs(sv) ** 2)
        for j in range(2**num_qubits):
            if prob_class[j] == classes[i]:
                c += prob[j]
        p[i] = c
    return p

# %%
loss = []
def callback(xk):
    loss.append(cost_function(xk))

result = minimize(cost_function, theta_values, method='COBYLA', callback=callback, options={'maxiter': maxiter})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       1 # loss = []
#       2 # def callback(xk):
#       3 #     loss.append(cost_function(xk))
# ----> 5 result = minimize(cost_function, theta_values, method='COBYLA', options={'maxiter': maxiter})
#
# File ~/anaconda3/envs/cuda-quantum/lib/python3.10/site-packages/scipy/optimize/_minimize.py:532, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#      51 def minimize(fun, x0, args=(), method=None, jac=None, hess=None,
#      52              hessp=None, bounds=None, constraints=(), tol=None,
#      53              callback=None, options=None):
#      54     """Minimization of scalar function of one or more variables.
#      55
#      56     Parameters
#    (...)
#     530
#     531     """
# --> 532     x0 = np.atleast_1d(np.asarray(x0))
#     534     if x0.ndim != 1:
#     535         raise ValueError("'x0' must only have one dimension.")
#
# File cupy/_core/core.pyx:1475, in cupy._core.core._ndarray_base.__array__()
#
# TypeError: Implicit conversion to a NumPy array is not allowed. Please use `.get()` to construct a NumPy array explicitly.

# %%
plt.plot(loss)

# %%
t_final = result.x
p_final = find_prob(data_values,t_final, class_values)
print(p_final)
# Out:
# [0.77720016 0.75741241 0.75761172 ... 0.46200778 0.88593337 0.37415615]

# %%
#Training data, Use only for binary classification
p_refined = np.zeros(m)
for i in range(m):
    if class_values[i] == 1:
        p_refined[i] = p_final[i]
    else:
        p_refined[i] = 1 - p_final[i]
roc_auc_score(class_values, p_refined)
# Out:
# 0.6306377034294894

# %%
# Compute ROC curve
fpr, tpr, thresholds = roc_curve(class_values, p_refined)

# Compute ROC AUC
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
#Test data, Use only for binary classification
p_test_final = find_prob(df_test_input,t_final, df_test_classes)
p_test_refined = np.zeros(len(df_test_classes))
for i in range(len(df_test_classes)):
    if df_test_classes[i] == 1:
        p_test_refined[i] = p_test_final[i]
    else:
        p_test_refined[i] = 1 - p_test_final[i]
roc_auc_score(df_test_classes, p_test_refined)
# Out:
# 0.7795289855072464
